# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# ### merge
# howに"inner","right","left","outer"を指定することで結合方式を選択

# %%
data = sns.load_dataset("titanic")
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
embarked = pd.DataFrame({"letter":["S", "C", "Q"], "town":data["embark_town"].dropna().unique().tolist()})
embarked.head()
# Out:
#   letter         town
# 0      S  Southampton
# 1      C    Cherbourg
# 2      Q   Queenstown

# %%
del data["embark_town"]
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck alive  alone
# 0    man        True  NaN    no  False
# 1  woman       False    C   yes  False
# 2  woman       False  NaN   yes   True
# 3  woman       False    C   yes  False
# 4    man        True  NaN    no   True

# %%
data = pd.merge(data, embarked, left_on="embarked", right_on="letter", how="inner")
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       3  female  26.0      0      0   7.9250        S  Third
# 2         1       1  female  35.0      1      0  53.1000        S  First
# 3         0       3    male  35.0      0      0   8.0500        S  Third
# 4         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male deck alive  alone letter_x       town_x letter_y  \
# 0    man        True  NaN    no  False        S  Southampton        S
# 1  woman       False  NaN   yes   True        S  Southampton        S
# 2  woman       False    C   yes  False        S  Southampton        S
# 3    man        True  NaN    no   True        S  Southampton        S
# 4    man        True    E    no   True        S  Southampton        S
#
#         town_y
# 0  Southampton
# 1  Southampton
# 2  Southampton
# 3  Southampton
# 4  Southampton

# %% [markdown]
# ### rolling
# 窓関数を適用する

# %%
flights = sns.load_dataset("flights")
flights.head(5)
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights["passengers"].rolling(center=False, window=3, min_periods=1).sum().head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-20d7d6be6d44> in <module>()
# ----> 1 flights["passengers"].rolling(center=False, window=3, min_periods=1).sum().head()
#
# NameError: name 'flights' is not defined

# %%
#窓の中心に結果の値を格納する
flights["passengers"].rolling(center=True, window=3, min_periods=1).sum().head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-af332e95570d> in <module>()
#       1 #窓の中心に結果の値を格納する
# ----> 2 flights["passengers"].rolling(center=True, window=3, min_periods=1).sum().head()
#
# NameError: name 'flights' is not defined

# %% [markdown]
# ### cross join
# * 全結合用の関数はないので自前で処理する

# %%
a = pd.DataFrame([1, 2, 3], columns=["a"])
a
# Out:
#    a
# 0  1
# 1  2
# 2  3

# %%
b = pd.DataFrame([4, 5, 6], columns=["b"])
b
# Out:
#    b
# 0  4
# 1  5
# 2  6

# %%
# 結合用に全て同じ値のキーを用意
a["key"] = 0
b["key"] = 0

# %%
ab = pd.merge(a, b, on="key")
ab.drop("key", axis=1)
# Out:
#    a  b
# 0  1  4
# 1  1  5
# 2  1  6
# 3  2  4
# 4  2  5
# 5  2  6
# 6  3  4
# 7  3  5
# 8  3  6
